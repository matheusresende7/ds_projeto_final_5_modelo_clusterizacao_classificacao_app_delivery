# %% [markdown]
# # 09. Deployment - Pandas

# %% [markdown]
# ## 09.1. Importação das bibliotecas

# %% [markdown]
# ### 09.1.1. Importando as bibliotecas nativas do Python

# %%
import sys

# %% [markdown]
# ### 09.1.2. Importando as bibliotecas de terceiros

# %%
import joblib
import pandas as pd

# %% [markdown]
# ### 09.1.3. Importando os módulos locais do projeto

# %%
sys.path.append('..')
import params.consts as consts

# %% [markdown]
# ## 09.2. Modelo de machine learning

# %% [markdown]
# ### 09.2.1. Carregando o grid search

# %%
grid_search_classification = joblib.load(consts.GRID_SEARCH_CLASSIFICATION_PANDAS_JOBLIB)

# %% [markdown]
# ### 09.2.2. Carregando o modelo

# %%
model_classification = joblib.load(consts.MODEL_CLASSIFICATION_PANDAS_JOBLIB)

# %% [markdown]
# ### 09.2.3. Verificando os hiperparâmetros testados

# %%
grid_search_classification.param_grid
# Out:
# {'feature_selection__k': [10, 15, 20, 25],
#  'models__C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03]),
#  'models__solver': ['liblinear', 'lbfgs', 'saga'],
#  'models__penalty': ['l1', 'l2', 'elasticnet', 'none']}

# %% [markdown]
# ### 09.2.4. Verificando os melhores hiperparâmetros selecionados

# %%
grid_search_classification.best_params_
# Out:
# {'feature_selection__k': 25,
#  'models__C': np.float64(10.0),
#  'models__penalty': 'l1',
#  'models__solver': 'saga'}

# %% [markdown]
# ### 09.2.5. Verificando o pipeline de treinamento do modelo

# %%
grid_search_classification.best_estimator_
# Out:
# Pipeline(steps=[('pre_processing',
#                  ColumnTransformer(transformers=[('one_hot_encoder',
#                                                   OneHotEncoder(),
#                                                   ['Education',
#                                                    'Marital_Status', 'AgeGroup',
#                                                    'Children', 'HasChildren',
#                                                    'Complain',
#                                                    'Years_Since_Enrolled',
#                                                    'AcceptedCmpTotal',
#                                                    'HasAcceptedCmp',
#                                                    'Cluster']),
#                                                  ('standard_scaler',
#                                                   StandardScaler(),
#                                                   ['Income', 'Age']),
#                                                  ('power_transformer',
#                                                   PowerTransformer(),
#                                                   ['NumDe...
#                                                    'NumTotalPurchases',
#                                                    'MntRegularProds',
#                                                    'MntGoldProds',
#                                                    'MntTotal']),
#                                                  ('min_max_scaler',
#                                                   MinMaxScaler(),
#                                                   ['Recency',
#                                                    'Dt_Customer_Month',
#                                                    'Dt_Customer_Quarter',
#                                                    'Days_Since_Enrolled'])])),
#                 ('feature_selection', SelectKBest(k=25)),
#                 ('resampling', RandomUnderSampler(random_state=42)),
#                 ('models',
#                  LogisticRegression(C=np.float64(10.0), penalty='l1',
#                                     random_state=42, solver='saga'))])

# %%
model_classification.named_steps
# Out:
# {'pre_processing': ColumnTransformer(transformers=[('one_hot_encoder', OneHotEncoder(),
#                                   ['Education', 'Marital_Status', 'AgeGroup',
#                                    'Children', 'HasChildren', 'Complain',
#                                    'Years_Since_Enrolled', 'AcceptedCmpTotal',
#                                    'HasAcceptedCmp', 'Cluster']),
#                                  ('standard_scaler', StandardScaler(),
#                                   ['Income', 'Age']),
#                                  ('power_transformer', PowerTransformer(),
#                                   ['NumDealsPurchases', 'NumWebVisitsMonth',
#                                    'NumTotalPurchases', 'MntRegularProds',
#                                    'MntGoldProds', 'MntTotal']),
#                                  ('min_max_scaler', MinMaxScaler(),
#                                   ['Recency', 'Dt_Customer_Month',
#                                    'Dt_Customer_Quarter',
#                                    'Days_Since_Enrolled'])]),
#  'feature_selection': SelectKBest(k=25),
#  'resampling': RandomUnderSampler(random_state=42),
#  'models': LogisticRegression(C=np.float64(10.0), penalty='l1', random_state=42,
#                     solver='saga')}

# %% [markdown]
# ### 09.2.6. Verificando os pré processamentos realizados nas colunas

# %%
model_classification.named_steps['pre_processing'].get_feature_names_out()
# Out:
# array(['one_hot_encoder__Education_2n Cycle',
#        'one_hot_encoder__Education_Basic',
#        'one_hot_encoder__Education_Graduation',
#        'one_hot_encoder__Education_Master',
#        'one_hot_encoder__Education_PhD',
#        'one_hot_encoder__Marital_Status_Partner',
#        'one_hot_encoder__Marital_Status_Single',
#        'one_hot_encoder__AgeGroup_18-30',
#        'one_hot_encoder__AgeGroup_31-45',
#        'one_hot_encoder__AgeGroup_46-60', 'one_hot_encoder__AgeGroup_61+',
#        'one_hot_encoder__Children_0', 'one_hot_encoder__Children_1',
#        'one_hot_encoder__Children_2', 'one_hot_encoder__Children_3',
#        'one_hot_encoder__HasChildren_0', 'one_hot_encoder__HasChildren_1',
#        'one_hot_encoder__Complain_0', 'one_hot_encoder__Complain_1',
#        'one_hot_encoder__Years_Since_Enrolled_0',
#        'one_hot_encoder__Years_Since_Enrolled_1',
#        'one_hot_encoder__AcceptedCmpTotal_0',
#        'one_hot_encoder__AcceptedCmpTotal_1',
#        'one_hot_encoder__AcceptedCmpTotal_2',
#        'one_hot_encoder__AcceptedCmpTotal_3',
#        'one_hot_encoder__AcceptedCmpTotal_4',
#        'one_hot_encoder__HasAcceptedCmp_0',
#        'one_hot_encoder__HasAcceptedCmp_1', 'one_hot_encoder__Cluster_0',
#        'one_hot_encoder__Cluster_1', 'one_hot_encoder__Cluster_2',
#        'standard_scaler__Income', 'standard_scaler__Age',
#        'power_transformer__NumDealsPurchases',
#        'power_transformer__NumWebVisitsMonth',
#        'power_transformer__NumTotalPurchases',
#        'power_transformer__MntRegularProds',
#        'power_transformer__MntGoldProds', 'power_transformer__MntTotal',
#        'min_max_scaler__Recency', 'min_max_scaler__Dt_Customer_Month',
#        'min_max_scaler__Dt_Customer_Quarter',
#        'min_max_scaler__Days_Since_Enrolled'], dtype=object)

# %% [markdown]
# ### 09.2.7. Verificando as melhores features selecionadas

# %%
model_classification.named_steps['pre_processing'].get_feature_names_out()[
    model_classification.named_steps['feature_selection'].get_support()
]
# Out:
# array(['one_hot_encoder__Education_PhD',
#        'one_hot_encoder__Marital_Status_Partner',
#        'one_hot_encoder__Marital_Status_Single',
#        'one_hot_encoder__Children_0', 'one_hot_encoder__Children_1',
#        'one_hot_encoder__HasChildren_0', 'one_hot_encoder__HasChildren_1',
#        'one_hot_encoder__Years_Since_Enrolled_0',
#        'one_hot_encoder__Years_Since_Enrolled_1',
#        'one_hot_encoder__AcceptedCmpTotal_0',
#        'one_hot_encoder__AcceptedCmpTotal_1',
#        'one_hot_encoder__AcceptedCmpTotal_2',
#        'one_hot_encoder__AcceptedCmpTotal_3',
#        'one_hot_encoder__AcceptedCmpTotal_4',
#        'one_hot_encoder__HasAcceptedCmp_0',
#        'one_hot_encoder__HasAcceptedCmp_1', 'one_hot_encoder__Cluster_0',
#        'one_hot_encoder__Cluster_1', 'standard_scaler__Income',
#        'power_transformer__NumTotalPurchases',
#        'power_transformer__MntRegularProds',
#        'power_transformer__MntGoldProds', 'power_transformer__MntTotal',
#        'min_max_scaler__Recency', 'min_max_scaler__Days_Since_Enrolled'],
#       dtype=object)

# %% [markdown]
# ## 09.3. Simulação do modelo

# %% [markdown]
# ### 09.3.1. Habilitando a exibição de todas as colunas e linhas

# %%
pd.set_option('display.max_columns', None); pd.set_option('display.max_rows', None)

# %% [markdown]
# ### 09.3.2. Armazenando o dataset em uma variável

# %%
df = pd.read_parquet(consts.DATASET_CLUSTERED_PANDAS)

# %% [markdown]
# ### 09.3.3. Visualizando a quantidade de linhas e colunas do dataset

# %%
df.shape
# Out:
# (2205, 23)

# %% [markdown]
# ### 09.3.4. Exibindo o dataset

# %%
df.head(5)
# Out:
#     Education Marital_Status  Children  HasChildren  Age AgeGroup   Income  \
# 0  Graduation         Single         0            0   57    46-60  58138.0
# 1  Graduation         Single         2            1   60    46-60  46344.0
# 2  Graduation        Partner         0            0   49    46-60  71613.0
# 3  Graduation        Partner         1            1   30    18-30  26646.0
# 4         PhD        Partner         1            1   33    31-45  58293.0
#
#    Recency  Complain  Dt_Customer_Month  Dt_Customer_Quarter  \
# 0       58         0                  9                    3
# 1       38         0                  3                    1
# 2       26         0                  8                    3
# 3       26         0                  2                    1
# 4       94         0                  1                    1
#
#    Days_Since_Enrolled  Years_Since_Enrolled  NumDealsPurchases  \
# 0                  663                     1                  3
# 1                  113                     0                  2
# 2                  312                     0                  1
# 3                  139                     0                  2
# 4                  161                     0                  5
#
#    NumWebVisitsMonth  NumTotalPurchases  MntRegularProds  MntGoldProds  \
# 0                  7                 22             1529            88
# 1                  5                  4               21             6
# 2                  4                 20              734            42
# 3                  6                  6               48             5
# 4                  5                 14              407            15
#
#    MntTotal  AcceptedCmpTotal  HasAcceptedCmp  Response  Cluster
# 0      1617                 0               0         1        2
# 1        27                 0               0         0        1
# 2       776                 0               0         0        0
# 3        53                 0               0         0        1
# 4       422                 0               0         0        2

# %% [markdown]
# ### 09.3.5. Definindo os valores a serem simulados no modelo

# %%
# Resultado esperado: 'Esse cliente DEVE aceitar a 6ª campanha'
Education = 'Graduation'
Marital_Status = 'Single'
Children = 0
Age = 31
Income = 86850.0
Recency = 15
Complain = 0
Dt_Customer_Month = 2
Days_Since_Enrolled = 180
NumDealsPurchases = 1
NumWebVisitsMonth = 2
NumTotalPurchases = 15
MntRegularProds = 800.00
MntGoldProds = 200.00
AcceptedCmpTotal = 2
Cluster = 0

HasChildren = 1 if Children > 0 else 0
AgeGroup = '18-30' if 18 <= Age <= 30 else '31-45' if 31 <= Age <= 45 else '46-60' if 46 <= Age <= 60 else '61+'
Dt_Customer_Quarter = ((Dt_Customer_Month - 1) // 3) + 1
Years_Since_Enrolled = int(Days_Since_Enrolled // 365)
MntTotal = MntRegularProds + MntGoldProds
HasAcceptedCmp = 1 if AcceptedCmpTotal > 0 else 0

# %%
# Resultado esperado: 'Esse cliente NÃO DEVE aceitar a 6ª campanha'
# Education = 'Graduation'
# Marital_Status = 'Single'
# Children = 0
# Age = 31
# Income = 16850.0
# Recency = 15
# Complain = 1
# Dt_Customer_Month = 2
# Days_Since_Enrolled = 180
# NumDealsPurchases = 1
# NumWebVisitsMonth = 2
# NumTotalPurchases = 15
# MntRegularProds = 100.00
# MntGoldProds = 20.00
# AcceptedCmpTotal = 0
# Cluster = 1

# HasChildren = 1 if Children > 0 else 0
# AgeGroup = '18-30' if 18 <= Age <= 30 else '31-45' if 31 <= Age <= 45 else '46-60' if 46 <= Age <= 60 else '61+'
# Dt_Customer_Quarter = ((Dt_Customer_Month - 1) // 3) + 1
# Years_Since_Enrolled = int(Days_Since_Enrolled // 365)
# MntTotal = MntRegularProds + MntGoldProds
# HasAcceptedCmp = 1 if AcceptedCmpTotal > 0 else 0

# %% [markdown]
# ### 09.3.6. Realizando a previsão com o modelo

# %%
data = pd.DataFrame({ 
    'Education': [Education], 
    'Marital_Status': [Marital_Status], 
    'Children': [Children], 
    'HasChildren': [HasChildren], 
    'Age': [Age], 
    'AgeGroup': [AgeGroup], 
    'Income': [Income], 
    'Recency': [Recency], 
    'Complain': [Complain], 
    'Dt_Customer_Month': [Dt_Customer_Month],
    'Dt_Customer_Quarter': [Dt_Customer_Quarter],
    'Days_Since_Enrolled': [Days_Since_Enrolled], 
    'Years_Since_Enrolled': [Years_Since_Enrolled],
    'NumDealsPurchases': [NumDealsPurchases], 
    'NumWebVisitsMonth': [NumWebVisitsMonth], 
    'NumTotalPurchases': [NumTotalPurchases], 
    'MntRegularProds': [MntRegularProds], 
    'MntGoldProds': [MntGoldProds], 
    'MntTotal': [MntTotal], 
    'AcceptedCmpTotal': [AcceptedCmpTotal], 
    'HasAcceptedCmp': [HasAcceptedCmp], 
    'Cluster': [Cluster]
})

prediction = model_classification.predict(data) 

if prediction == 1:

    print(f'Esse cliente DEVE aceitar a 6ª campanha.')

elif prediction == 0:

    print(f'Esse cliente NÃO DEVE aceitar a 6ª campanha.')
# Out:
# Esse cliente DEVE aceitar a 6ª campanha.

# %% [markdown]
# ## 09.4. Implementação do modelo

# %% [markdown]
# ### 09.4.1. Realizando o deploy do modelo em formato ipynb

# %% [markdown]
# 1. Crie um arquivo conforme o modelo, renome-o para **"dataset_deploy.csv"** e coloque-o na pasta **"deploys"** desse projeto
# 2. Na pasta **"deploys"**, abra o arquivo **"classification_notebook.ipynb"** e execute-o
# 3. Pronto, as previsões foram feitas. Para acessá-las é só abrir o novo arquivo criado na pasta **"deploys"** chamado **"dataset_deployed.csv"**

# %% [markdown]
# ### 09.4.2. Realizando o deploy do modelo em formato py

# %% [markdown]
# 1. Crie um arquivo conforme o modelo, renome-o para **"dataset_deploy.csv"** e coloque-o na pasta **"deploys"** desse projeto
# 2. No **terminal**, digite **cd + "caminho da pasta"** (o caminho deve estar entre aspas) e dê enter para entrar na pasta pelo terminal. Para copiar o caminho da pasta basta navegar até o arquivo no explorador de arquivos, clicar no caminho exibido na barra de navegação e copiar
# 3. Agora digite **python classification_python.py** e dê enter
# 4. Pronto, as previsões foram feitas. Para acessá-las é só abrir o novo arquivo criado na pasta **"deploys"** chamado **"dataset_deployed.csv"**

# %% [markdown]
# ### 09.4.3. Realizando o deploy do modelo em um arquivo executável

# %% [markdown]
# Nesse projeto, não será utilizado o deploy do modelo em um arquivo executável devido a ter a necessidade de se criar um ambiente virtual para que esse arquivo executável possa ser executado em qualquer local. A principal justificativa para isso é que em um ambiente virtual é preciso instalar todas as bibliotecas usadas durante o projeto, o que tornaria o arquivo muito grande e portanto, inviável para subir no Github.

# %% [markdown]
# ### 09.4.4. Realizando o deploy do modelo em Streamlit (.py)

# %% [markdown]
# 1. No **terminal**, digite **cd + "caminho da pasta"** (o caminho deve estar entre aspas) e dê enter para entrar na pasta pelo terminal. Para copiar o caminho da pasta basta navegar até o arquivo no explorador de arquivos, clicar no caminho exibido na barra de navegação e copiar
# 2. Agora digite **streamlit run classification_streamlit.py** e dê enter
# 3. Pronto, as previsões foram feitas. A resposta do modelo é exibida na própria tela ao preencher todos os campos
